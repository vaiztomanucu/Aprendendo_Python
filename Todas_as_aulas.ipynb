# %% [markdown]
# <a href="https://colab.research.google.com/github/vaiztomanucu/Aprendendo_Python/blob/master/Todas_as_aulas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Aula 1

# %%
import pandas as pd

# %%
df = pd.read_csv("https://raw.githubusercontent.com/guilhermeonrails/data-jobs/refs/heads/main/salaries.csv")

# %%
df.head(10)
# Out:
#    work_year experience_level employment_type           job_title  salary  \
# 0     2025.0               SE              FT  Solutions Engineer  214000
# 1     2025.0               SE              FT  Solutions Engineer  136000
# 2     2025.0               MI              FT       Data Engineer  158800
# 3     2025.0               MI              FT       Data Engineer  139200
# 4     2025.0               EN              FT       Data Engineer   90000
# 5     2025.0               EN              FT       Data Engineer   80000
# 6     2025.0               SE              FT      Data Scientist  185000
# 7     2025.0               SE              FT      Data Scientist  148000
# 8     2025.0               MI              FT      Data Scientist  135000
# 9     2025.0               MI              FT      Data Scientist  108000
#
#   salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0             USD         214000                 US           100
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 133349 entries, 0 to 133348
# Data columns (total 11 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   work_year           133339 non-null  float64
#  1   experience_level    133349 non-null  object
#  2   employment_type     133349 non-null  object
#  3   job_title           133349 non-null  object
#  4   salary              133349 non-null  int64
#  5   salary_currency     133349 non-null  object
#  6   salary_in_usd       133349 non-null  int64
#  7   employee_residence  133349 non-null  object
#  8   remote_ratio        133349 non-null  int64
#  9   company_location    133349 non-null  object
#  10  company_size        133349 non-null  object
# dtypes: float64(1), int64(3), object(7)
# memory usage: 11.2+ MB

# %%
df.describe()
# Out:
#            work_year        salary  salary_in_usd   remote_ratio
# count  133339.000000  1.333490e+05  133349.000000  133349.000000
# mean     2024.358770  1.632833e+05  157617.272098      20.905669
# std         0.680627  2.173860e+05   74288.363097      40.590044
# min      2020.000000  1.400000e+04   15000.000000       0.000000
# 25%      2024.000000  1.060200e+05  106000.000000       0.000000
# 50%      2024.000000  1.470000e+05  146206.000000       0.000000
# 75%      2025.000000  1.990000e+05  198000.000000       0.000000
# max      2025.000000  3.040000e+07  800000.000000     100.000000

# %%
df.shape
# Out:
# (133349, 11)

# %%
linhas, colunas = df.shape[0], df.shape[1]
print(f'Linhas: {linhas}\nColunas: {colunas}')
# Out:
# Linhas: 133349
# Colunas: 11

# %%
df.columns
# Out:
# Index(['work_year', 'experience_level', 'employment_type', 'job_title',
#        'salary', 'salary_currency', 'salary_in_usd', 'employee_residence',
#        'remote_ratio', 'company_location', 'company_size'],
#       dtype='object')

# %%
df.columns = [
    'ano',
    'seneoridade',
    'contrato',
    'cargo',
    'salario',
    'moeda',
    'usd',
    'residencia',
    'remoto',
    'empresa',
    'tamanho_empresa'
]

print(df.columns)
# Out:
# Index(['ano', 'seneoridade', 'contrato', 'cargo', 'salario', 'moeda', 'usd',
#        'residencia', 'remoto', 'empresa', 'tamanho_empresa'],
#       dtype='object')

# %%
#Para essa tradução usamos IA, o próprio Gemini está configurdo para funcionar juntamente com o colab.
#Caso não traduzisse automaticamente, os comandos seriam os seguintes:
#renomear_colunas = {'work_year': 'ano'}
#df.rename(columns=renomear_colunas, inplace=True)
#df.columns

# %%
df['seneoridade'].value_counts()
# Out:
# seneoridade
# SE    77241
# MI    40465
# EN    12443
# EX     3200
# Name: count, dtype: int64

# %%
df['contrato'].value_counts()
# Out:
# contrato
# FT    132563
# CT       394
# PT       376
# FL        16
# Name: count, dtype: int64

# %%
df['remoto'].value_counts()
# Out:
# remoto
# 0      105312
# 100     27718
# 50        319
# Name: count, dtype: int64

# %%
df['tamanho_empresa'].value_counts()
# Out:
# tamanho_empresa
# M    129561
# L      3574
# S       214
# Name: count, dtype: int64

# %%
df['seneoridade'] = df['seneoridade'].replace({
    'SE': 'Sênior',
    'MI': 'Pleno',
    'EN': 'Júnior',
    'EX': 'Executivo'
})
df['seneoridade'].value_counts()
# Out:
# seneoridade
# Sênior       77241
# Pleno        40465
# Júnior       12443
# Executivo     3200
# Name: count, dtype: int64

# %%
#Acima, utilizamos IA novamente para traduzir para português as siglas das colunas da tabela
#Abaixo, repeti o mesmo processo para as demais
#SEMPRE LEMBRAR DE VERIFICAR SE ESTÁ TUDO CORRETO APÓS USO DA IA!!!!!

# %%
df['contrato'] = df['contrato'].replace({
    'FT': 'Tempo Integral',
    'CT': 'Contrato',
    'PT': 'Meio Período',
    'FL': 'Freelancer'
})
print("Contrato (atualizado):")
print(df['contrato'].value_counts())
# Out:
# Contrato (atualizado):
# contrato
# Tempo Integral    132563
# Contrato             394
# Meio Período         376
# Freelancer            16
# Name: count, dtype: int64

# %%
df['remoto'] = df['remoto'].replace({
    0: 'Presencial',
    100: 'Remoto',
    50: 'Híbrido'
})
print("\nRemoto (atualizado):")
print(df['remoto'].value_counts())
# Out:
# Remoto (atualizado):
# remoto
# Presencial    105312
# Remoto         27718
# Híbrido          319
# Name: count, dtype: int64

# %%
df['tamanho_empresa'] = df['tamanho_empresa'].replace({
    'M': 'Médio',
    'L': 'Grande',
    'S': 'Pequeno'
})
print("\nTamanho da Empresa (atualizado):")
print(df['tamanho_empresa'].value_counts())
# Out:
# Tamanho da Empresa (atualizado):
# tamanho_empresa
# Médio      129561
# Grande       3574
# Pequeno       214
# Name: count, dtype: int64

# %%
df.head()
# Out:
#       ano seneoridade        contrato               cargo  salario moeda  \
# 0  2025.0      Sênior  Tempo Integral  Solutions Engineer   214000   USD
# 1  2025.0      Sênior  Tempo Integral  Solutions Engineer   136000   USD
# 2  2025.0       Pleno  Tempo Integral       Data Engineer   158800   USD
# 3  2025.0       Pleno  Tempo Integral       Data Engineer   139200   USD
# 4  2025.0      Júnior  Tempo Integral       Data Engineer    90000   USD
#
#       usd residencia      remoto empresa tamanho_empresa
# 0  214000         US      Remoto      US           Médio
# 1  136000         US      Remoto      US           Médio
# 2  158800         AU  Presencial      AU           Médio
# 3  139200         AU  Presencial      AU           Médio
# 4   90000         US  Presencial      US           Médio

# %%
df['cargo'] = df['cargo'].replace({
    'Data Engineer': 'Engenheiro de Dados',
    'Data Scientist': 'Cientista de Dados',
    'Data Analyst': 'Analista de Dados',
    'Machine Learning Engineer': 'Engenheiro de Machine Learning',
    'Analytics Engineer': 'Engenheiro de Análise',
    'Research Scientist': 'Cientista de Pesquisa',
    'Applied Scientist': 'Cientista Aplicado',
    'ML Engineer': 'Engenheiro de ML',
    'Cloud Engineer': 'Engenheiro de Nuvem',
    'AI Engineer': 'Engenheiro de IA',
    'Software Engineer': 'Engenheiro de Software',
    'Data Architect': 'Arquiteto de Dados',
    'Solutions Engineer': 'Engenheiro de Soluções'
})
print(df['cargo'].value_counts().head(10))
# Out:
# cargo
# Cientista de Dados                17315
# Engenheiro de Software            15007
# Engenheiro de Dados               14868
# Analista de Dados                 12381
# Engineer                           9456
# Engenheiro de Machine Learning     8205
# Manager                            6679
# Analyst                            4364
# Cientista de Pesquisa              3202
# Product Manager                    2230
# Name: count, dtype: int64

# %%
df.head()
# Out:
#       ano seneoridade        contrato                   cargo  salario moeda  \
# 0  2025.0      Sênior  Tempo Integral  Engenheiro de Soluções   214000   USD
# 1  2025.0      Sênior  Tempo Integral  Engenheiro de Soluções   136000   USD
# 2  2025.0       Pleno  Tempo Integral     Engenheiro de Dados   158800   USD
# 3  2025.0       Pleno  Tempo Integral     Engenheiro de Dados   139200   USD
# 4  2025.0      Júnior  Tempo Integral     Engenheiro de Dados    90000   USD
#
#       usd residencia      remoto empresa tamanho_empresa
# 0  214000         US      Remoto      US           Médio
# 1  136000         US      Remoto      US           Médio
# 2  158800         AU  Presencial      AU           Médio
# 3  139200         AU  Presencial      AU           Médio
# 4   90000         US  Presencial      US           Médio

# %%
df.describe(include='object')
# Out:
#        seneoridade        contrato               cargo   moeda residencia  \
# count       133349          133349              133349  133349     133349
# unique           4               4                 389      26        102
# top         Sênior  Tempo Integral  Cientista de Dados     USD         US
# freq         77241          132563               17315  126140     119579
#
#             remoto empresa tamanho_empresa
# count       133349  133349          133349
# unique           3      95               3
# top     Presencial      US           Médio
# freq        105312  119641          129561

# %%
df.describe()
# Out:
#                  ano       salario            usd
# count  133339.000000  1.333490e+05  133349.000000
# mean     2024.358770  1.632833e+05  157617.272098
# std         0.680627  2.173860e+05   74288.363097
# min      2020.000000  1.400000e+04   15000.000000
# 25%      2024.000000  1.060200e+05  106000.000000
# 50%      2024.000000  1.470000e+05  146206.000000
# 75%      2025.000000  1.990000e+05  198000.000000
# max      2025.000000  3.040000e+07  800000.000000

# %% [markdown]
# # Aula 2

# %%
df.isnull() #False para dado nulo ou True onde existe dados.
# Out:
#           ano  seneoridade  contrato  cargo  salario  moeda    usd  \
# 0       False        False     False  False    False  False  False
# 1       False        False     False  False    False  False  False
# 2       False        False     False  False    False  False  False
# 3       False        False     False  False    False  False  False
# 4       False        False     False  False    False  False  False
# ...       ...          ...       ...    ...      ...    ...    ...
# 133344  False        False     False  False    False  False  False
# 133345  False        False     False  False    False  False  False
# 133346  False        False     False  False    False  False  False
# 133347  False        False     False  False    False  False  False
# 133348  False        False     False  False    False  False  False
#
#         residencia  remoto  empresa  tamanho_empresa
# 0            False   False    False            False
# 1            False   False    False            False
# ...

# %%
df.head()
# Out:
#       ano seneoridade        contrato                   cargo  salario moeda  \
# 0  2025.0      Sênior  Tempo Integral  Engenheiro de Soluções   214000   USD
# 1  2025.0      Sênior  Tempo Integral  Engenheiro de Soluções   136000   USD
# 2  2025.0       Pleno  Tempo Integral     Engenheiro de Dados   158800   USD
# 3  2025.0       Pleno  Tempo Integral     Engenheiro de Dados   139200   USD
# 4  2025.0      Júnior  Tempo Integral     Engenheiro de Dados    90000   USD
#
#       usd residencia      remoto empresa tamanho_empresa
# 0  214000         US      Remoto      US           Médio
# 1  136000         US      Remoto      US           Médio
# 2  158800         AU  Presencial      AU           Médio
# 3  139200         AU  Presencial      AU           Médio
# 4   90000         US  Presencial      US           Médio

# %%
df.isnull().sum() #Somou todos nulos em cada coluna.
# Out:
# ano                10
# seneoridade         0
# contrato            0
# cargo               0
# salario             0
# moeda               0
# usd                 0
# residencia          0
# remoto              0
# empresa             0
# tamanho_empresa     0
# dtype: int64

# %%
df['ano'].unique() #Valores únicos dentro da coluna específicada.
# Out:
# array([2025.,   nan, 2024., 2022., 2023., 2020., 2021.])

# %%
df[df.isnull().any(axis=1)] #Para filtrar em quais posições está os valores nulos.
# Out:
#         ano seneoridade        contrato                           cargo  \
# 5588    NaN      Sênior  Tempo Integral                 Product Manager
# 59692   NaN       Pleno  Tempo Integral                        Engineer
# 59710   NaN      Júnior  Tempo Integral              Cientista de Dados
# 59759   NaN      Sênior  Tempo Integral          Engenheiro de Software
# 59789   NaN      Sênior  Tempo Integral                        Engineer
# 131000  NaN      Sênior  Tempo Integral  Engenheiro de Machine Learning
# 131006  NaN      Sênior  Tempo Integral          Data Analytics Manager
# 133054  NaN      Júnior  Tempo Integral              Cientista de Dados
# 133281  NaN       Pleno  Tempo Integral  Engenheiro de Machine Learning
# 133317  NaN       Pleno  Tempo Integral              Cientista de Dados
#
#         salario moeda     usd residencia      remoto empresa tamanho_empresa
# 5588     184500   USD  184500         US  Presencial      US           Médio
# ...

# %%
import numpy as np #Importando a biblioteca numpy e apelidando para np.
df_salarios = pd.DataFrame({
    'nome': ["Ana", "Bruno", "Carlos", "Daniele", "Val"],
    'salário': [4000, np.nan, 5000, np.nan, 100000]
}) #Criando um dataframe com os dados acima, np.nan significa valor nulo.

df_salarios['salario_media'] = df_salarios['salário'].fillna(df_salarios['salário'].mean().round(2))
#O comando acima serve para criar uma nova coluna, 'salario_media'. Fillna para preencher valores nulos com a média(mean) dos salários e round(2) para arredondar com duas casas decimais.
df_salarios['salario_mediana'] = df_salarios['salário'].fillna(df_salarios['salário'].median())
df_salarios
# Out:
#       nome   salário  salario_media  salario_mediana
# 0      Ana    4000.0        4000.00           4000.0
# 1    Bruno       NaN       36333.33           5000.0
# 2   Carlos    5000.0        5000.00           5000.0
# 3  Daniele       NaN       36333.33           5000.0
# 4      Val  100000.0      100000.00         100000.0

# %%
df_temperaturas = pd.DataFrame({
    #Criando outro dataframe para exemplificar comandos.
    "Dias da semana" : ['Segunda', 'Terça', 'Quarta', 'Quinta', 'Sexta'],
    'Temperatura' : [30, np.nan, np.nan, 28, 27]
})
#ffill preenche com o valor anterior ao nulo, neste caso, 30.
df_temperaturas['Preenchido_ffill'] = df_temperaturas['Temperatura'].ffill()
#bfill preenche com o valor posterior ao nulo.
df_temperaturas['Preenchido_bfill'] = df_temperaturas['Temperatura'].bfill()
df_temperaturas
# Out:
#   Dias da semana  Temperatura  Preenchido_ffill  Preenchido_bfill
# 0        Segunda         30.0              30.0              30.0
# 1          Terça          NaN              30.0              28.0
# 2         Quarta          NaN              30.0              28.0
# 3         Quinta         28.0              28.0              28.0
# 4          Sexta         27.0              27.0              27.0

# %%
df_cidades = pd.DataFrame({
    'nome' :  ["Ana", "Bruno", "Carlos", "Daniele", "Val"],
    'cidade' : ["São Paulo", np.nan, "Curitiba", np.nan, "Belém"]
})
df_cidades['cidade_preenchida'] = df_cidades['cidade'].fillna('Não informado')
df_cidades
# Out:
#       nome     cidade cidade_preenchida
# 0      Ana  São Paulo         São Paulo
# 1    Bruno        NaN     Não informado
# 2   Carlos   Curitiba          Curitiba
# 3  Daniele        NaN     Não informado
# 4      Val      Belém             Belém

# %%
df_limpo = df.dropna() #Criando nova variável para não mexer diretamente na anterior e sobrepor.

# %%
df_limpo.isnull().sum()
# Out:
# ano                0
# seneoridade        0
# contrato           0
# cargo              0
# salario            0
# moeda              0
# usd                0
# residencia         0
# remoto             0
# empresa            0
# tamanho_empresa    0
# dtype: int64

# %%
df_limpo.head()
# Out:
#       ano seneoridade        contrato                   cargo  salario moeda  \
# 0  2025.0      Sênior  Tempo Integral  Engenheiro de Soluções   214000   USD
# 1  2025.0      Sênior  Tempo Integral  Engenheiro de Soluções   136000   USD
# 2  2025.0       Pleno  Tempo Integral     Engenheiro de Dados   158800   USD
# 3  2025.0       Pleno  Tempo Integral     Engenheiro de Dados   139200   USD
# 4  2025.0      Júnior  Tempo Integral     Engenheiro de Dados    90000   USD
#
#       usd residencia      remoto empresa tamanho_empresa
# 0  214000         US      Remoto      US           Médio
# 1  136000         US      Remoto      US           Médio
# 2  158800         AU  Presencial      AU           Médio
# 3  139200         AU  Presencial      AU           Médio
# 4   90000         US  Presencial      US           Médio

# %%
df_limpo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 133339 entries, 0 to 133348
# Data columns (total 11 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   ano              133339 non-null  float64
#  1   seneoridade      133339 non-null  object
#  2   contrato         133339 non-null  object
#  3   cargo            133339 non-null  object
#  4   salario          133339 non-null  int64
#  5   moeda            133339 non-null  object
#  6   usd              133339 non-null  int64
#  7   residencia       133339 non-null  object
#  8   remoto           133339 non-null  object
#  9   empresa          133339 non-null  object
#  10  tamanho_empresa  133339 non-null  object
# dtypes: float64(1), int64(2), object(8)
# memory usage: 12.2+ MB

# %%
df_limpo = df_limpo.assign(ano = df_limpo['ano'].astype('int64'))
#Aqui usamos o assign para reconfigurar e o astype para trocar o tipo de variável na coluna ano.

# %% [markdown]
# # Aula 3

# %%
df_limpo.head()
# Out:
#     ano seneoridade        contrato                   cargo  salario moeda  \
# 0  2025      Sênior  Tempo Integral  Engenheiro de Soluções   214000   USD
# 1  2025      Sênior  Tempo Integral  Engenheiro de Soluções   136000   USD
# 2  2025       Pleno  Tempo Integral     Engenheiro de Dados   158800   USD
# 3  2025       Pleno  Tempo Integral     Engenheiro de Dados   139200   USD
# 4  2025      Júnior  Tempo Integral     Engenheiro de Dados    90000   USD
#
#       usd residencia      remoto empresa tamanho_empresa
# 0  214000         US      Remoto      US           Médio
# 1  136000         US      Remoto      US           Médio
# 2  158800         AU  Presencial      AU           Médio
# 3  139200         AU  Presencial      AU           Médio
# 4   90000         US  Presencial      US           Médio

# %%
df_limpo['seneoridade'].value_counts().plot(kind='bar',title='Distribuição de seneoridade')
#1º selecionamos a coluna seneoridade
#2º valores da coluna
#3º gere um gráfico gráfico 'plot', kind para o tipo de gráfico e adicionamos um título
# Out:
# <Axes: title={'center': 'Distribuição de seneoridade'}, xlabel='seneoridade'>

# %%
import seaborn as sns

# %%
sns.barplot(data=df_limpo, x='seneoridade', y='usd')
# O primeiro comando é da própria biblioteca, para gerar um gráfico de colunas.
# Data = 'base de dados' e após isso selecionar as colunas que irão em cada eixo.
# Out:
# <Axes: xlabel='seneoridade', ylabel='usd'>

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(8, 5)) # Definição do tamanho da figura.
sns.barplot(data=df_limpo, x='seneoridade', y='usd') # Gerar gráfico.
# Definição do título e rótulos de eixos.
plt.title('Salário médio por nível de seneoridade')
plt.xlabel('Seneoridade')
plt.ylabel('Salário médio anual em USD')
plt.show() # Para apresentar a imagem

# %%
# Usamos o comando groupby na base de dados para agrupar e ordenar a média das colunas
df_limpo.groupby('seneoridade')['usd'].mean().sort_values(ascending=False)
# Out:
# seneoridade
# Executivo    202027.667813
# Sênior       172850.838301
# Pleno        143044.845979
# Júnior        99034.963267
# Name: usd, dtype: float64

# %%
ordem = df_limpo.groupby('seneoridade')['usd'].mean().sort_values(ascending=True).index
#Para salvar em uma variável, True = menor ao maior, False = maior ao menor.
ordem
# Out:
# Index(['Júnior', 'Pleno', 'Sênior', 'Executivo'], dtype='object', name='seneoridade')

# %%
plt.figure(figsize=(8, 5)) # Definição do tamanho da figura.
sns.barplot(data=df_limpo, x='seneoridade', y='usd', order=ordem) # Gerar gráfico.
# Definição do título e rótulos de eixos.
plt.title('Salário médio por nível de seneoridade')
plt.xlabel('Seneoridade')
plt.ylabel('Salário médio anual em USD')
plt.show() # Para apresentar a imagem

# %%
plt.figure(figsize=(8, 4))
sns.histplot(df_limpo['usd'], bins = 50, kde = True)
plt.title('Distribuição dos salários anuais')
plt.xlabel('Salário em USD')
plt.ylabel('Frequência')
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.boxplot(x=df_limpo['usd'])
plt.title('Boxplot Salário')
plt.xlabel('Salário em USD')
plt.show()

# %%
ordem_seneoridade = ['Júnior', 'Pleno', 'Sênior', 'Executivo']
plt.figure(figsize=(8, 5))
sns.boxplot(x='seneoridade', y='usd', data=df_limpo, order=ordem_seneoridade)
plt.title('Distribuição salarial por seneoridade')
plt.xlabel('Salário em USD')
plt.ylabel('USD')
plt.show()

# %%
ordem_seneoridade = ['Júnior', 'Pleno', 'Sênior', 'Executivo']
plt.figure(figsize=(8, 5))
sns.boxplot(x='seneoridade', y='usd', data=df_limpo, order=ordem_seneoridade, palette='Set2', hue='seneoridade')
# Foi adicionado os parâmetros 'palette' para paleta de cor e 'hue' para especificar onde irão as cores.
plt.title('Distribuição salarial por seneoridade')
plt.xlabel('Salário em USD')
plt.ylabel('USD')
plt.show()

# %%
import plotly.express as px

# %%
df_media_salario_seneoridade = df_limpo.groupby('seneoridade')['usd'].mean().reset_index()

fig = px.bar(
    df_media_salario_seneoridade,
    x='seneoridade',
    y='usd',
    title='Salário Médio Anual por Nível de Senioridade',
    labels={'seneoridade': 'Nível de Senioridade', 'usd': 'Salário Médio Anual em USD'},
    color='seneoridade',
    category_orders={'seneoridade': ['Júnior', 'Pleno', 'Sênior', 'Executivo']}
)

fig.update_layout(xaxis_title='Senioridade', yaxis_title='Salário Médio Anual (USD)')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
remoto_contagem = df_limpo['remoto'].value_counts().reset_index()
remoto_contagem.columns = ['tipo_trabalho', 'quantidade']
fig = px.pie(
    remoto_contagem,
    names = 'tipo_trabalho',
    values = 'quantidade',
    title= 'Proporção dos Tipos de Trabalho'
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
remoto_contagem = df_limpo['remoto'].value_counts().reset_index()
remoto_contagem.columns = ['tipo_trabalho', 'quantidade']
fig = px.pie(
    remoto_contagem,
    names = 'tipo_trabalho',
    values = 'quantidade',
    title= 'Proporção dos Tipos de Trabalho',
    hole=0.5

)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
emoto_contagem = df_limpo['remoto'].value_counts().reset_index()
remoto_contagem.columns = ['tipo_trabalho', 'quantidade']
fig = px.pie(
    remoto_contagem,
    names = 'tipo_trabalho',
    values = 'quantidade',
    title= 'Proporção dos Tipos de Trabalho',
    hole=0.5

)
fig.update_traces(textinfo = 'percent+label')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # Aula 4

# %%
pip install pycountry

# %%
import pycountry

# %%
# Função para converter ISO-2 para ISO-3
def iso2_to_iso3(code):
    try:
        return pycountry.countries.get(alpha_2=code).alpha_3
    except:
        return None

# Criar nova coluna com código ISO-3
df_limpo['residencia_iso3'] = df_limpo['residencia'].apply(iso2_to_iso3)

# Calcular média salarial por país (ISO-3)
df_ds = df_limpo[df_limpo['cargo'] == 'Data Scientist']
media_ds_pais = df_ds.groupby('residencia_iso3')['usd'].mean().reset_index()

# Gerar o mapa
fig = px.choropleth(media_ds_pais,
                    locations='residencia_iso3',
                    color='usd',
                    color_continuous_scale='rdylgn',
                    title='Salário médio de Cientista de Dados por país',
                    labels={'usd': 'Salário médio (USD)', 'residencia_iso3': 'País'})

fig.show()


df_limpo.head()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df_limpo.to_csv('dados-imersao-final.csv', index=False)
